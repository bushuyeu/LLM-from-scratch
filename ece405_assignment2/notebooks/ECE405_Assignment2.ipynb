# %% [markdown]
# # ECE405 Assignment 2 — Data Filtering for Language Modeling
#
# Based on CS336 Assignment 4 (Stanford, Spring 2025)

# %% [markdown]
# ## 2.1 Looking at the data

# %% [markdown]
# ### Setup: Download sample WARC and WET files

# %%
import os, shutil

# --- Configuration ---
REPO_URL = "https://github.com/bushuyeu/LLM-from-scratch.git"
REPO_DIR = "/content/LLM-from-scratch"
ASSIGNMENT_DIR = os.path.join(REPO_DIR, "ece405_assignment2")
BRANCH = "main"

# Clone / update the repo on the Colab kernel
if os.path.exists(os.path.join(REPO_DIR, ".git")):
    # !git -C {REPO_DIR} pull
else:
    # Clean up any leftover non-git directory
    if os.path.exists(REPO_DIR):
        shutil.rmtree(REPO_DIR)
    # !git clone -b {BRANCH} {REPO_URL} {REPO_DIR}

# Install dependencies:
# 1. Common pip packages needed by the notebook and cs336-data
# !pip install -q warcio resiliparse fasttext tldextract xopen "numpy<2.0" tqdm nltk mmh3

# 2. cs336-basics (local sub-package required by cs336-data)
# !pip install -e {ASSIGNMENT_DIR}/cs336-basics

# 3. cs336-data itself (--no-deps because pip can't resolve the uv-specific
#    local-path source for cs336-basics; we already installed it above)
# !pip install --no-deps -e {ASSIGNMENT_DIR}

# Verify install
# !pip show cs336-data

# Set up data directory
DATA_DIR = os.path.join(ASSIGNMENT_DIR, "data")
os.makedirs(DATA_DIR, exist_ok=True)

# %%
WARC_URL = "https://data.commoncrawl.org/crawl-data/CC-MAIN-2025-18/segments/1744889135610.12/warc/CC-MAIN-20250417135010-20250417165010-00065.warc.gz"
WET_URL = "https://data.commoncrawl.org/crawl-data/CC-MAIN-2025-18/segments/1744889135610.12/wet/CC-MAIN-20250417135010-20250417165010-00065.warc.wet.gz"

WARC_PATH = os.path.join(DATA_DIR, "example.warc.gz")
WET_PATH = os.path.join(DATA_DIR, "example.warc.wet.gz")

# %%
# Download WARC file (approx 1GB compressed)
if not os.path.exists(WARC_PATH):
    # !wget -O {WARC_PATH} "{WARC_URL}"
else:
    print(f"WARC file already exists at {WARC_PATH}")
# Out:
# WARC file already exists at /content/LLM-from-scratch/ece405_assignment2/data/example.warc.gz

# %%
# Download WET file
if not os.path.exists(WET_PATH):
    # !wget -O {WET_PATH} "{WET_URL}"
else:
    print(f"WET file already exists at {WET_PATH}")
# Out:
# WET file already exists at /content/LLM-from-scratch/ece405_assignment2/data/example.warc.wet.gz

# %% [markdown]
# ### (a) Examine the first page in the WARC file

# %%
from warcio.archiveiterator import ArchiveIterator

with open(WARC_PATH, "rb") as f:
    for i, record in enumerate(ArchiveIterator(f)):
        print(f"Record {i}: type={record.rec_type}")
        if record.rec_type == "response":
            print(f"  URL: {record.rec_headers.get_header('WARC-Target-URI')}")
            print(f"  Date: {record.rec_headers.get_header('WARC-Date')}")
            print(f"  Content-Type: {record.http_headers.get_header('Content-Type') if record.http_headers else 'N/A'}")
            print()
            # Print first 3000 chars of HTML content
            content = record.content_stream().read()
            print("--- First 3000 chars of raw content ---")
            print(content[:3000].decode('utf-8', errors='replace'))
            break
# Out:
# Record 0: type=warcinfo
# Record 1: type=request
# Record 2: type=response
#   URL: http://0371rykj.com/ipfhsb/34.html
#   Date: 2025-04-17T14:56:33Z
#   Content-Type: text/html
#
# --- First 3000 chars of raw content ---
# <!DOCTYPE html>
# <html>
#  <head>
#    <meta charset="UTF-8">
#
#   <title>&#x4EBA;&#x59BB;&#x2C;&#x56FD;&#x5185;&#x8001;&#x719F;&#x5987;&#x5BF9;&#x767D;&#x48;&#x44;&#x58;&#x58;&#x58;&#x58;&#x2C;&#x4E9A;&#x6D32;&#x41;&#x56;&#x65E0;&#x7801;&#x4E00;&#x533A;&#x4E1C;&#x4EAC;&#x70ED;&#x4E45;&#x4E45;&#x0D;</title>
#   <meta name="keywords" content="&#x4EBA;&#x59BB;&#x2C;&#x56FD;&#x5185;&#x8001;&#x719F;&#x5987;&#x5BF9;&#x767D;&#x48;&#x44;&#x58;&#x58;&#x58;&#x58;&#x2C;&#x4E9A;&#x6D32;&#x41;&#x56;&#x65E0;&#x7801;&#x4E00;&#x533A;&#x4E1C;&#x4EAC;&#x70ED;&#x4E45;&#x4E45;&#x0D;" />
#   <meta name="description" content="&#x4EBA;&#x59BB;&#x2C;&#x56FD;&#x5185;&#x8001;&#x719F;&#x5987;&#x5BF9;&#x767D;&#x48;&#x44;&#x58;&#x58;&#x58;&#x58;&#x2C;&#x4E9A;&#x6D32;&#x41;&#x56;&#x65E0;&#x7801;&#x4E00;&#x533A;&#x4E1C;&#x4EAC;&#x70ED;&#x4E45;&#x4E45;&#x0D;&#x2C;&#x39;&#x39;&#x39;&#x4E45;&#x4E45;&#x4E45;&#x514D;&#x8D39;&#x7CBE;&#x54C1;&#x56FD;&#x4EA7;&#x2C;&#x56FD;&#x4EA7;&#x7CBE;&#x54C1;&#x6210;&#x4EBA;&#x56FD;&#x4EA7;&#x4E71;&#x2C;&#x8089;&#x8272;&#x8D85;&#x8584;&#x4E1D;&#x889C;&#x811A;&#x4EA4;&#x4E00;&#x533A;&#x4E8C;&#x533A;" />
#
#
#
#  <link href="/style/css/animate.min.css" type="text/css" rel="stylesheet" />
#      <link href="/style/css/resetcommon.css" rel="stylesheet" type="text/css" />
#      <link href="/style/css/style.css" type="text/css" rel="stylesheet" />
# <script type="text/javascript" src="/style/js/js.js"></script>
#   <script type="text/javascript" src="/style/js/scrollbar.js"></script>
# 	 <link rel="stylesheet" type="text/css" href="/style/css/xzoom.css" media="all" />
# 	<script src="/style/js/jquery.js" type="text/javascript"></script>
# 	<script type="text/javascript" src="/style/js/xzoom.min.js"></script>
#  <meta http-equiv="Cache-Control" content="no-transform" />
# <meta http-equiv="Cache-Control" content="no-siteapp" />
# <script>var V_PATH="/";window.onerror=function(){ return true; };</script>
# </head>
#  <body>
# <h1><a href="http://0371rykj.com/">&#x4E45;&#x4E45;&#x4E45;&#x4E45;&#x5973;&#x4EBA;&#x7CBE;&#x54C1;&#x6BDB;&#x7247;&#x2C;&#x39;&#x39;&#x4E45;&#x4E45;&#x7CBE;&#x54C1;&#x65E0;&#x7801;&#x4E00;&#x533A;&#x4E8C;&#x533A;&#x6BDB;&#x7247;&#x2C;&#x88AB;&#x8001;&#x5916;&#x7684;&#x53C8;&#x7C97;&#x53C8;&#x5927;&#x65E5;&#x51FA;&#x4E86;&#x6C34;&#x2C;&#x4E00;&#x8FB9;&#x5403;&#x5976;&#x4E00;&#x8FB9;&#x54ED;&#x4E71;&#x62BB;&#x53C8;&#x4E71;&#x626D;</a></h1>
# <div id="gckmo" class="pl_css_ganrao" style="display: none;"><sup id="gckmo"></sup><optgroup id="gckmo"></optgroup><rt id="gckmo"></rt><blockquote id="gckmo"></blockquote><center id="gckmo"><pre id="gckmo"><xmp id="gckmo"></xmp></pre></center><optgroup id="gckmo"></optgroup><kbd id="gckmo"></kbd><bdo id="gckmo"></bdo><nav id="gckmo"></nav><tbody id="gckmo"><button id="gckmo"><samp id="gckmo"></samp></button></tbody><dl id="gckmo"></dl><table id="gckmo"></table><pre id="gckmo"></pre><dd id="gckmo"><th id="gckmo"><menu id="gckmo"></menu></th></dd><acronym id="gckmo"><dd id="gckmo"><th id="gckmo"></th></

# %% [markdown]
# ### (b) Examine the corresponding WET file

# %%
with open(WET_PATH, "rb") as f:
    for i, record in enumerate(ArchiveIterator(f)):
        if record.rec_type == "conversion":
            url = record.rec_headers.get_header('WARC-Target-URI')
            content = record.content_stream().read().decode('utf-8', errors='replace')
            print(f"URL: {url}")
            print(f"Content length: {len(content)} chars")
            print()
            print("--- Extracted text (first 3000 chars) ---")
            print(content[:3000])
            break
# Out:
# URL: http://0371rykj.com/ipfhsb/34.html
# Content length: 3496 chars
#
# --- Extracted text (first 3000 chars) ---
# 人妻,国内老熟妇对白HDXXXX,亚洲AV无码一区东京热久久
# 久久久久女人精品毛片,99久久精品无码一区二区毛片,被老外的又粗又大日出了水,一边吃奶一边哭乱抻又乱扭
# 恒溫恒濕試驗(yàn)箱
# 在線(xiàn)咨詢(xún)
# 上海林頻儀器股份有限公司Shanghai Linpin Instrument Stock Co Ltd
# 服務(wù)熱線(xiàn)：4000 662 888
# 手機(jī)咨詢(xún)：13818467052
# 首頁(yè)
# 林頻產(chǎn)品
# 試驗(yàn)箱系列
# 老化箱系列
# 非標(biāo)定制系列
# ip防護(hù)系列
# 振動(dòng)跌落系列
# 成功案例
# 新聞中心
# 林頻新聞
# 行業(yè)新聞
# 常見(jiàn)問(wèn)題
# 解決方案
# 關(guān)于林頻
# 服務(wù)支持
# 聯(lián)系我們
# 您所在的位置：
# 恒溫恒濕試驗(yàn)箱 > 林頻產(chǎn)品 > ip防護(hù)系列 >
# 產(chǎn)品詳情/ products details
# 恒溫恒濕試驗(yàn)箱
# 產(chǎn)品用途
# 恒溫恒濕試驗(yàn)箱是航空、汽車(chē)、家電、科研等領(lǐng)域必備的測(cè)試設(shè)備，用于測(cè)試和確定電工、電子及其他產(chǎn)品及材料進(jìn)行高溫、低溫、濕熱度或恒定試驗(yàn)的溫度環(huán)境變化后的參數(shù)及性能。...
# 了解詳情 立即咨詢(xún)
# 產(chǎn)品參數(shù) / parameter
# 設(shè)備型號(hào) 工作室尺寸(D*W*H)mm 外型尺寸(D*W*H)mm
# LRHS-101-LH 450×450×500 1160×1000×1610
# LRHS-225-LH 500×600×750 1210×1150×1870
# LRHS-504-LH 700×800×900 1260×1340×2070
# LRHS-800-LH 800×1000×1000 1370×1550×2170
# LRHS-1000-LH 1000×1000×1000 1560×1550×2170
# 性
# 能
# 指
# 標(biāo) 溫度范圍 0℃～150℃
# 溫度均勻度 ≤2℃（空載時(shí)）
# 溫度波動(dòng)度 ±0.5℃（空載時(shí)）
# 濕度范圍 20%～98% RH
# 濕度均勻度 +2% -3% RH
# 濕度波動(dòng) ±2%
# 升溫速率 1.0～3.0℃/min
# 降溫速率 0.7～1.0℃/min
# 時(shí)間設(shè)定范圍 1～60000M
# 測(cè)試孔 安裝在機(jī)器左側(cè)，用于外接測(cè)試電源線(xiàn)或信號(hào)線(xiàn)使用
# 觀(guān)察窗 210×275mm或395×395mm（有效視界）
# 使
# 用
# 材
# 料 外箱材質(zhì) 優(yōu)質(zhì)A3鋼板靜電噴塑
# 內(nèi)箱材質(zhì) 進(jìn)口高級(jí)不銹鋼SUS304
# 保溫材質(zhì) 硬質(zhì)聚氨酯泡沫+玻璃纖維
# 核
# 心
# 配
# 置 溫度控制器 日本原裝進(jìn)口“優(yōu)易控”品牌溫濕度儀表
# 溫度傳感器 PT100鉑金電阻測(cè)溫體
# 制冷方式 單機(jī)制冷
# 壓 縮 機(jī) 法國(guó)泰康
# 標(biāo)準(zhǔn)配置 濕球紗布1卷、樣品架2層、配有凝結(jié)水接水盤(pán)，并排出箱外
# 安全保護(hù) 壓縮機(jī)過(guò)熱、超壓、超溫、風(fēng)機(jī)電機(jī)過(guò)熱、整體設(shè)備欠相/逆相 整體設(shè)備定時(shí)、漏電保護(hù)、
# 過(guò)載及短路保護(hù)
# 電源電壓 AC380V±10% 50Hz
# 功 率 4.0KW/5.5KW/8.5KW/11.5KW/11.5KW
# 使用環(huán)境 5℃～＋28℃ ≤85% RH
# 注：
# 1、以上數(shù)據(jù)均在使用環(huán)境溫度為25℃時(shí)且通風(fēng)良好條件下測(cè)得
# 2、可根據(jù)用戶(hù)具體試驗(yàn)要求非標(biāo)定制恒溫恒濕試驗(yàn)室等
# 3、本技術(shù)信息，如有變動(dòng)恕不另行通知
# 上一篇：武漢冷凝水試驗(yàn)箱|冷凝水實(shí)驗(yàn)箱|冷凝水測(cè)試箱使用說(shuō)明 下一篇：武漢軍標(biāo)淋雨試驗(yàn)室|軍標(biāo)淋雨實(shí)驗(yàn)箱|軍標(biāo)淋雨箱
# ip防護(hù)系列
# 試驗(yàn)箱系列
# 復(fù)合鹽霧箱
# 轉(zhuǎn)臺(tái)試驗(yàn)箱
# 高低溫試驗(yàn)箱
# 酒精低溫沖擊槽
# 老化箱系列
# 低溫綜合試驗(yàn)箱
# 水冷氙燈耐氣候試驗(yàn)箱
# 風(fēng)冷氙燈耐氣候試驗(yàn)箱
# 新能源電池試驗(yàn)箱
# 非標(biāo)定制系列
# 步入式老化房
# IP9K防水試驗(yàn)室
# 濕度試驗(yàn)測(cè)試箱
# 步入式高低溫試驗(yàn)箱
# ip防護(hù)系列
# 擺管淋雨實(shí)驗(yàn)裝置
# 恒溫恒濕試驗(yàn)箱
# 箱式?jīng)_水試驗(yàn)箱
# 防塵試驗(yàn)箱
# 振動(dòng)跌落系列
# 振動(dòng)試驗(yàn)臺(tái)
# 跌落試驗(yàn)機(jī)
# 咨詢(xún)熱線(xiàn)4000 662 888
# 查看更多
# 關(guān)于林頻
# 上海林頻儀器股份有限公司
# 上海林頻儀器股份有限公司是可靠性環(huán)境試驗(yàn)設(shè)備行業(yè)中的股份制高新技術(shù)企業(yè)，專(zhuān)業(yè)的試驗(yàn)設(shè)備制造商和試驗(yàn)解決方案綜合服務(wù)商，擁有標(biāo)準(zhǔn)化的試驗(yàn)設(shè)備生產(chǎn)基地和設(shè)備展示廳。 憑借創(chuàng)新的產(chǎn)品、高效的供應(yīng)鏈和強(qiáng)大的戰(zhàn)略執(zhí)行力，林頻儀器銳意為廣大用戶(hù)打造優(yōu)質(zhì)、安全、環(huán)保的產(chǎn)品及專(zhuān)業(yè)高效的服務(wù)。 [查看詳情]
# 查看更多
# 新聞動(dòng)態(tài)
# 手掌間的自然韻律：恒溫恒濕箱的
# 在科技的浪潮中，有一種設(shè)備靜靜地佇立在實(shí)驗(yàn)室或儲(chǔ)存空間里，它不言不語(yǔ)，... [查看詳情]
# 手掌間的自然韻律：恒溫恒濕箱的科技魅力
# 恒溫恒濕試驗(yàn)箱：AI算法優(yōu)化實(shí)現(xiàn)多模態(tài)數(shù)據(jù)監(jiān)測(cè)
# 手電筒防護(hù)等級(jí)驗(yàn)證：鹽霧試驗(yàn)箱的標(biāo)準(zhǔn)測(cè)試方
# 探索恒溫恒濕試驗(yàn)箱在工業(yè)領(lǐng)域的使用與發(fā)展
# 恒溫恒濕試驗(yàn)箱下電子產(chǎn)品可靠性試驗(yàn)過(guò)程研究
# 恒溫恒濕試驗(yàn)箱：探索未知領(lǐng)域的勇敢探險(xiǎn)家
# 溫度與濕度雙重控制-恒溫恒濕試驗(yà

# %% [markdown]
# ### (d) Annotate 25 WET records

# %%
with open(WET_PATH, "rb") as f:
    count = 0
    for record in ArchiveIterator(f):
        if record.rec_type == "conversion":
            url = record.rec_headers.get_header('WARC-Target-URI')
            content = record.content_stream().read().decode('utf-8', errors='replace')
            print(f"\n{'='*80}")
            print(f"Record {count + 1}")
            print(f"URL: {url}")
            print(f"Content length: {len(content)} chars")
            print(f"First 500 chars:")
            print(content[:500])
            print(f"{'='*80}")
            count += 1
            if count >= 25:
                break
# Out:
# ================================================================================
# Record 1
# URL: http://0371rykj.com/ipfhsb/34.html
# Content length: 3496 chars
# First 500 chars:
# 人妻,国内老熟妇对白HDXXXX,亚洲AV无码一区东京热久久
# 久久久久女人精品毛片,99久久精品无码一区二区毛片,被老外的又粗又大日出了水,一边吃奶一边哭乱抻又乱扭
# 恒溫恒濕試驗(yàn)箱
# 在線(xiàn)咨詢(xún)
# 上海林頻儀器股份有限公司Shanghai Linpin Instrument Stock Co Ltd
# 服務(wù)熱線(xiàn)：4000 662 888
# 手機(jī)咨詢(xún)：13818467052
# 首頁(yè)
# 林頻產(chǎn)品
# 試驗(yàn)箱系列
# 老化箱系列
# 非標(biāo)定制系列
# ip防護(hù)系列
# 振動(dòng)跌落系列
# 成功案例
# 新聞中心
# 林頻新聞
# 行業(yè)新聞
# 常見(jiàn)問(wèn)題
# 解決方案
# 關(guān)于林頻
# 服務(wù)支持
# 聯(lián)系我們
# 您所在的位置：
# 恒溫恒濕試驗(yàn)箱 > 林頻產(chǎn)品 > ip防護(hù)系列 >
# 產(chǎn)品詳情/ products details
# 恒溫恒濕試驗(yàn)箱
# 產(chǎn)品用途
# 恒溫恒濕試驗(yàn)箱是航空、汽車(chē)、家電、科研等領(
# ================================================================================
#
# ================================================================================
# Record 2
# URL: http://10www.chinatikfans.com/home.php?mod=space&uid=4693&do=blog&classid=104&view=me
# Content length: 2066 chars
# First 500 chars:
# lily_zl的日志 - &#1769;杰西达邦中国影迷会&#1769; - Powered by Discuz!
# 设为首页收藏本站
# 开启辅助访问 切换到窄版
# 帐号 自动登录 找回密码
# 密码
# 登录
# 加入我们
# 只需一步，快速开始
# 快捷导航
# 广场BBS
# 家园Space
# 每日签到
# 排行榜Ranklist
# 手机论坛
# 搜索
# 搜索
# 用户
# &#1769;杰西达邦中国影迷会&#1769; › 日志
# 际遇
# 发布 日志
# 上传 相册
# 添加 分享
# 记录
# 日志
# 好友的日志
# 我的日志
# 随便看看
# 发表新日志
# discussion on plots| my creation| 杂谈| Tik的新消息| Peach| Wanida| Tik的图片|
# 分享 记录下这一天：《两地相思》发布下载和在线
# lily_zl 2010-6-28 12:27
# 呵呵，昨天在朋友的帮助下我尝试用了新办法合并视频，成功的感觉挺好的。虽然从等待翻译、落实片源，到制作字幕、压制、合并、上传一系列过程很繁琐，也很费时；虽然做出来的东西不是尽善尽美，但依旧是开心的。真正是累并快乐着。 现在，2003年的tik杰西达邦和Maam K McIntosh
# ================================================================================
#
# ================================================================================
# Record 3
# URL: http://13.usnccm.org/
# Content length: 2232 chars
# First 500 chars:
# Welcome to USNCCM13! | USNCCM 13
# Skip to main content
# USNCCM 13
# 13th US National Congress on Computational Mechanics
# San Diego, CA
# July 26-30, 2015
# Main menu
# Home
# Congress Information
# Important Dates
# Organization
# Local Organizing Committee
# Scientific Organizing Committee
# USACM Advisory Committee
# Contact
# Congress Co-Chairs
# Administrative Contact
# Plenary and Semi-Plenary Speakers
# Minisymposia
# Congress Minisymposia
# Minisymposia Organizers' Page
# Abstract Submission
# Program
# Technical Program
# Social P
# ================================================================================
#
# ================================================================================
# Record 4
# URL: http://176.utchat888.com/index.phtml?PUT=gift_send&AID=220083&FID=632054
# Content length: 1566 chars
# First 500 chars:
# 專打飛機
# 專打飛機
# 影音視訊聊天室
# 依照網站分級規定未滿十八歲者請勿瀏覽
# 24小時客服專線 : 02-27654066 傳真 : 02-27659081
# 與我們聯絡 | 加入會員 |
# 首頁
# $賺錢聯盟$
# 頻道排行榜
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** -贈點10,000 點 No.2 LV28160** -贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點
# No.7 LV37566** -贈點4,000 點 No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# 頻道指數 限制級(火辣) 輔導級(曖昧) 普通級(清純)
# 排序 業績排行│ 一對多收費排序│ 一對一收費排序
# Hi!
# 會員專區
# 帳號:
# 密碼:
# 請輸入圖片驗證碼
# 購買點數
# 加入會員
# 忘記密碼
# 新手上路
# 常見問題
# 付
# ================================================================================
#
# ================================================================================
# Record 5
# URL: http://176766.cn/Article-3806781.html
# Content length: 2103 chars
# First 500 chars:
# 人人操人人干人人色,欧美日韩国产综合在线一区二区
# 人妻久久久久久久久久久久久,国产午夜精品福利在线观看,色道久久综合亚洲精品蜜桃,国产欧美日韩另类精彩视频
# 13382153105
# 網(wǎng)站首頁
# 關(guān)于我們
# 產(chǎn)品展示
# 行業(yè)資訊
# 技術(shù)支持
# 在線商店
# 在線留言
# 聯(lián)系我們
# 產(chǎn)品展示
# PRODUCT DISPLAY
# 硬度測試儀
# 洛氏硬度計
# 塑料洛氏硬度計
# 表面洛氏硬度計
# 顯微硬度計
# 維氏硬度計
# 布氏硬度計
# 布洛維硬度計
# 塑料球壓痕硬度計
# 斷裂韌性測試儀
# 氧化膜厚度硬度計
# 鋁材硬度計
# 里氏硬度計
# 邵氏硬度計
# 金相制樣設(shè)備
# 金相試樣切割機
# 金相鑲嵌機
# 磨拋機
# 預磨機
# 拋光機
# 電解拋光機
# 晶間腐蝕儀
# 光譜砂帶磨樣機
# 電子萬能試驗機
# 數(shù)顯電子萬能試驗機
# 微機控制電子萬能試驗機
# 液壓萬能試驗機
# 電液伺服萬能試驗機
# 數(shù)顯式液壓萬能試驗機
# 微機屏顯液壓萬能試驗機
# 微機控制伺服萬能試驗機
# 壓力試驗機
# 數(shù)顯式壓力試驗機
# 微機控制伺服壓力試驗機
# 沖擊試驗機
# 低溫沖擊試驗機
# 金屬擺錘沖擊試驗機
# 顯微鏡
# 偏光
# ================================================================================
#
# ================================================================================
# Record 6
# URL: http://178mh.com/html/,detail/,newsmovie/,wd/moAGt5YrbE/po7oqy.html,/
# Content length: 17 chars
# First 500 chars:
# detail.html 模板不存在
# ================================================================================
#
# ================================================================================
# Record 7
# URL: http://1796370.tgtg97.com/?PUT=a_show&AID=266989&FID=1796370&R2=&CHANNEL=
# Content length: 5177 chars
# First 500 chars:
# live173影音live秀 - 主播 :: 神仙表姐
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** -贈點10,000 點 No.2 LV28160** -贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點
# No.7 LV37566** -贈點4,000 點 No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# 業績排行 | 分鐘數 | 已消費會員數 | 平均分鐘數 | 會員評價 | 上線時間 | 聊天人緣 | 包廂線上人數
# | 一對多點數 | 一對一點數 | 網站新人 | 上線狀態排序 | 網站推薦 | 談情說愛 | 成人視訊 搜尋主持人：
# (神仙表姐) 最近上線時間 : 2025-04-15 13:45:54
# 免費聊天 進入包廂 送禮 給主持人打分數 個人首頁 | 相片本 |
# ================================================================================
#
# ================================================================================
# Record 8
# URL: http://18sex.v340.info/?&R2=&P=11&OP=&CHANNEL=
# Content length: 2440 chars
# First 500 chars:
# 本土自拍性愛影片
# 回 首 頁 │ 點數購買 │ 付款方式 │ 加入會員 │會員登入 │主持人登入 │ 線上客服 │使用說明 │ 使用條款 │
# 台妹區 | 內地主播區 | 業績排行 | 會員評價 | 包廂線上人數
# | 一對多點數 | 一對一點數 | 上線狀態排序 | 網站推薦 | 已審核本人照 | 談情說愛 | 成人視訊
# 統計時間為星期一至每週星期日，每周日會重新統計數據。
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** -贈點10,000 點 No.2 LV28160** -贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點
# No.7 LV37566** -贈點4,000 點 No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# 手機行動裝置請先下載APP才能進入主播包廂
# QR Co
# ================================================================================
#
# ================================================================================
# Record 9
# URL: http://1kb.klimtoren.be/2016/06/blog-post_30.html
# Content length: 1143 chars
# First 500 chars:
# 1KB - Juf Marijke
# 1KB - Juf Marijke
# donderdag 30 juni 2016
# Hoera voor Leonie!
# 4 Jaar :-)
# Gepost door juf marijke op 09:22
# Dit e-mailen Dit bloggen!Delen via XDelen op FacebookDelen op Pinterest
# Geen opmerkingen:
# Een reactie posten
# Nieuwere post Oudere post Homepage
# Abonneren op: Reacties posten (Atom)
# Blogarchief
# ► 2018 (40)
# ► juni (10)
# ► mei (6)
# ► april (10)
# ► maart (4)
# ► februari (5)
# ► januari (5)
# ► 2017 (78)
# ► december (9)
# ► november (3)
# ► oktober (9)
# ► september (5)
# ► augustus (1)
# ► juli (3)
# ================================================================================
#
# ================================================================================
# Record 10
# URL: http://1pekesat-exae.mysch.gr/exae/search.php?sid=c7c6170adb93afd9c9d00950dd818d3d
# Content length: 1915 chars
# First 500 chars:
# Helpdesk εξΑΕ 1ου ΠΕΚΕΣ Αττικής - Αναζήτηση
# Helpdesk εξΑΕ 1ου ΠΕΚΕΣ Αττικής
# Υποστηρικτική Ομάδα για την εξ αποστάσεως Εκπαίδευση
# Μετάβαση στο περιεχόμενο
# Γρήγορες συνδέσεις
# Αναπάντητα θέματα
# Ενεργά θέματα
# Αναζήτηση
# Συχνές ερωτήσεις
# Σύνδεση
# Εγγραφή
# Ευρετήριο Δ. Συζήτησης Αναζήτηση
# Αναζήτηση
# Ερώτημα αναζήτησης
# Αναζήτηση για λέξεις-κλειδιά:
# Τοποθετήστε το + μπροστά από μια λέξη που πρέπει να βρεθεί και - μπροστά από μια λέξη που δεν πρέπει να βρεθεί. Βάλτε μια λίστα με λέξεις που χωρίζονται με | σε
# ================================================================================
#
# ================================================================================
# Record 11
# URL: http://1pekesat-exae.mysch.gr/exae/ucp.php?mode=login&redirect=ucp.php%3Fmode%3Ddelete_cookies&sid=895ec649188d0e4bfff2f75f02ff8b0a
# Content length: 1169 chars
# First 500 chars:
# Helpdesk εξΑΕ 1ου ΠΕΚΕΣ Αττικής - Πίνακας Ελέγχου Μέλους - Σύνδεση
# Helpdesk εξΑΕ 1ου ΠΕΚΕΣ Αττικής
# Υποστηρικτική Ομάδα για την εξ αποστάσεως Εκπαίδευση
# Μετάβαση στο περιεχόμενο
# Αναζήτηση
# Ειδική αναζήτηση
# Γρήγορες συνδέσεις
# Αναπάντητα θέματα
# Ενεργά θέματα
# Αναζήτηση
# Συχνές ερωτήσεις
# Σύνδεση
# Εγγραφή
# Ευρετήριο Δ. Συζήτησης
# Αναζήτηση
# Σύνδεση
# Όνομα μέλους:
# Κωδικός πρόσβασης:
# Ξέχασα τον κωδικό μου
# Να με θυμάσαι
# Απόκρυψη των στοιχείων μου κατά τη διάρκεια της σύνδεσης
# Εγγραφή
# Προκειμένου να συνδεθείτε π
# ================================================================================
#
# ================================================================================
# Record 12
# URL: http://1s6605084.yhxzseo.com/?yibinnvfdkcl857593
# Content length: 1954 chars
# First 500 chars:
# 澳客竞彩比分/旧版本APP-畅享精彩，轻松下载体验
# 硬件
# APP下载
# 请登录登录
# 首页
# 资讯栏目
# 手机笔记本影像DIY外设家电办公企业要闻专题
# 特色栏目
# 聚超值IT百科产品报价维修信息发布会视频专区视频直播图赏新品速递AI智造高校
# PConline2025-4-6 02:24:27
# 王标,孟妍
# 随着体育赛事的不断增多，越来越多的球迷开始关注各类比赛的结果和动态。在这样的背景下，澳客竞彩比分应运而生，成为球迷们获取赛事信息和比分数据的重要平台。无论是足球、篮球还是其他各类体育项目，用户都可以通过这个平台获取实时的比分更新、赛程安排、数据分析等信息，为他们的观赛体验增添更多乐趣。
# 在使用澳客竞彩比分的过程中，用户可以享受到简洁明了的界面设计，方便快捷的操作流程。无论你是资深球迷，还是刚刚接触体育赛事的小白，都可以在这里找到自己需要的信息。通过平台的智能推荐系统，用户能够根据自己的兴趣爱好，获取个性化的赛事推荐，进一步提升观赛的乐趣。
# 此外，澳客竞彩比分还为用户提供了丰富的赛事资讯和深度解析。用户不仅可以查看到实时的比分，还可以阅读到专业的赛事分析和评论，帮助他们更好地理解比赛的动态。在这里
# ================================================================================
#
# ================================================================================
# Record 13
# URL: http://20com20.fr/manual/tr/sitemap.html
# Content length: 8329 chars
# First 500 chars:
# Site Haritası - Apache HTTP Sunucusu Sürüm 2.4
# Modüller | Yönergeler | SSS | Terimler | Site Haritası
# Apache HTTP Sunucusu Sürüm 2.4
# Apache > HTTP Sunucusu > Belgeleme > Sürüm 2.4
# Site Haritası
# Mevcut Diller: de | en | es | fr | ja | ko | tr | zh-cn
# Bu sayfada Apache HTTP Sunucusu Sürüm 2.4 Belgelerinin tamamı listelenmiştir.
# Sürümlerin Dağıtım Bilgileri
# Apache HTTP Sunucusunun Kullanımı
# Apache Sanal Konak (VirtualHost) Belgeleri
# URL’lerin Yeniden Yazılması
# Apache SSL/TLS Şifrelemesi
# Kılavuzlar,
# ================================================================================
#
# ================================================================================
# Record 14
# URL: http://24ktcasino.net/2019/06/25/laos-casinos-4/
# Content length: 2856 chars
# First 500 chars:
# ﻿ Laos Casinos » Casino Tips
# Home
# Content
# RSS
# Log in
# Casino Tips
# Online Casino Tips
# Search for:
# Home
# Laos Casinos
# June 25th, 2019 by Nikhil Leave a reply »
# Read more about the
# Las Vegas 2024 Super
# Bowl Streaker!
# Set amongst Thailand and Vietnam, Laos is one of the true jewels of Southeast Asia. While some parts of it might not be as highly developed as its Indochina counterparts, there is one area where it has managed to hang in – casino gambling.
# The Dansavanh Casino is located in Ban Muang Wa-
# ================================================================================
#
# ================================================================================
# Record 15
# URL: http://2kgames.eu/rizqhy/706105255.shtml
# Content length: 34 chars
# First 500 chars:
# 404 Not Found
# 404 Not Found
# nginx
#
# ================================================================================
#
# ================================================================================
# Record 16
# URL: http://2l6185919.yizhangting.com/?shaoguan65gdkcl329611
# Content length: 4353 chars
# First 500 chars:
# 福利彩票论坛/游戏平台APP-畅享极致休闲娱乐
# 内分泌资讯
# 快速导航
# 频道
# 女性
# 减肥
# 育儿
# 保健
# 美容
# 妇科
# 饮食
# 中医
# 肿瘤
# 资讯
# 男性
# 诊疗
# 呼吸科
# 心血管
# 肝病科
# 更多
# 服务
# 问医生
# 就医助手
# 药品通
# 疾病百科
# 名医在线
# 简单生活
# 热门疾病
# 高血压
# 阴道炎
# 肩周炎
# 脂肪肝
# 小儿咳嗽
# 糖尿病
# 健康科普
# 科普基地
# 关注39减肥健康运动
# 查看更多相关内容
# 取消关注
# 首页>内分泌与代谢>内分泌资讯
# 福利彩票论坛/测试版APP-畅享极致娱乐体验
# 举报/反馈
# 2025-4-17 15:50:2439健康网
# 在当今互联网快速发展的时代，越来越多的人选择在线参与各种活动，而福利彩票作为一种受欢迎的公益活动，吸引了越来越多的参与者。福利彩票论坛为广大用户提供了一个交流、分享和获取最新信息的平台。无论你是对福利彩票玩法感兴趣，还是想了解最新的中奖资讯，亦或是希望结识志同道合的朋友，这里都能满足你的需求。
# 首先，福利彩票论坛为用户提供了丰富的内容。用户可以在这里找到关于各类福利彩票的详细介绍，包括各个地区的玩法规则、购票指南等。此外，论坛还定期更新有关最新开奖信息和中奖公告，让用户不错过任何一份机会
# ================================================================================
#
# ================================================================================
# Record 17
# URL: http://303323.com/xydt/dnqgqzl-65615.html
# Content length: 1027 chars
# First 500 chars:
# 電凝切割器助力微創胃腸道手術：減少術后疼痛 - 鑫海合星科技（大連）有限公司
# 歡迎您光臨鑫海合星科技（大連）有限公司官方網站 ！
# 站點地圖 | 關于我們 | XML | 您有4條詢盤信息 ！
# 聯系電話：13602737580
# 首頁
# 公司簡介
# 產品展示
# 新聞中心
# 下載中心
# 招商合作
# 人才中心
# 聯系我們
# 熱門關鍵詞： 一次性使用膽道鏡 一次性使用宮腔鏡 射頻消融電極 一次性消融電極 消融電極
# 產品 新聞 媒體
# 新聞中心
# 常見問題
# 信息平臺
# 行業動態
# 聯系我們
# 鑫海合星科技（大連）有限公司
# 聯 系 人：王盛明
# 聯系電話：13602737580
# 0411-39245188
# 傳 真：0411-39245188
# 公司地址：大連經濟技術開發區港興大街聯東U谷77-28號
# 當前位置：首頁 》 新聞中心 》 行業動態 》 電凝切割器助力微創胃腸道手術：減少術后疼痛
# 電凝切割器助力微創胃腸道手術：減少術后疼痛
# 文章出處：鑫海合星科技（大連）有限公司責任編輯：人氣：202發表時間：2025/3/5
# 電凝切割器助力微創胃腸道手術：減少術后疼痛
# 胃腸道手術的微創化是當前醫學界的重要趨勢 。電凝切割器的應用不僅優
# ================================================================================
#
# ================================================================================
# Record 18
# URL: http://30bad.com/edu-46963.html
# Content length: 3916 chars
# First 500 chars:
# 动漫-《CLASSIC★STARS–古典乐★之星》-免费-手机在线观看 - 真不卡影院 电影盒子
# 清空 播放记录
# 首页
# 电影
# 电视剧
# 动漫
# 综艺
# 伦理
# 妹子
# 【真不卡影院 电影盒子】为您提供《CLASSIC★STARS–古典乐★之星》免费在线观看地址，以及CLASSIC★STARS–古典乐★之星剧情简介、主演、上映更新时间、和影片播出时间、同类型、同主演等内容。
# 当前位置 首页 动漫 《CLASSIC★STARS–古典乐★之星》
# 更新至第02集
# CLASSIC★STARS–古典乐★之星
# 类型：动漫 地区：日本 年份：2025
# 主演：内详
# 导演：内详
# 更新：2025-04-13 08:15:08
# 简介： 这是一部以音乐梦想为主题的励志影片CLASSIC★STARS–古典乐★之星讲述一群热爱古典音乐的年轻人在追逐梦想的道路上克服重重困难最终通过不懈努力和团队合作实现了自我突破并登上国际舞台的故事影片通… 详情
# 立即播放
# 播放地址
# 优酷视频
# 奇异视频
# 第01集
# 第02集
# 第01集
# 第02集
# 剧情介绍
# 欢迎在线观看由内详等主演在2025年的动漫《CLASSIC★STARS–古典乐★之星》，真不
# ================================================================================
#
# ================================================================================
# Record 19
# URL: http://312001.net/home/djdt/list
# Content length: 570 chars
# First 500 chars:
# 党建动态-绍兴市越城区皋埠街道社区卫生服务中心
# 网站首页
# 医院介绍
# 绍兴概况 医院概况 医院历史 基地/工作站 领导致辞 领导介绍 组织结构 医院环境 高新设备 医院荣誉 执业信息
# 新闻中心
# 医院动态 媒体报道
# 医疗服务
# 科室介绍 专家荟萃 特色诊疗 就医指南 预约挂号 查询服务 专家咨询 健康教育 专家门诊
# 护理园地
# 护理团队 护理动态 优质护理 天使文苑 护理科普
# 科研教学
# 重点学科 规培中心 科研成果 医学教学 论文发表 表格下载 GCP专栏
# 院务公开
# 医院公告 收费标准 行风建设 规章制度 阳光用药 廉政文化 床位信息
# 医院文化
# 院标创意 文化长廊 皋医理念 学习交流 医院视频 职工摄影 人事招聘
# 党建在线
# 党纪党规 高层声音 两学一做 党建动态 党务公开
# 专题专栏
# 医联体专栏 医院重点工作计划 创建“优质医院” “三好一满意”活动 公共卫生服务
# 党建在线
# 党纪党规
# 高层声音
# 两学一做
# 党建动态
# 党务公开
# 您现在所在位置：首页 党建在线 党建动态 党建动态
# 我为“七一”添光彩 百场千医大型义诊活动2021-06-24
# 绍兴市越城区皋埠街道社区卫生服务中心 版权所有 地址：浙江省
# ================================================================================
#
# ================================================================================
# Record 20
# URL: http://354577.mwe075.com/index.phtml?PUT=a_show&AID=257266&FID=354577&R2=&CHANNEL=
# Content length: 6751 chars
# First 500 chars:
# 約愛神器
# 會員登入 加入會員 查詢密碼
# 任何的意見與問題 請聯繫 在線客服
# 免費文字聊天區 一對一視訊聊天 / 免費一對多視訊 搜尋主持人：
# 業績排行 │ 分鐘數排行 │ 本站推薦 │ 本月新人 │ 一對多收費排序 │ 一對一收費排序
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** - 贈點10,000 點 No.2 LV28160** - 贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點 No.7 LV37566** -贈點4,000 點
# No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# ~ 感謝大家對本平台的支持與愛護, 也恭喜以上會員
# (靈凌) 我在休息 最近上線時間 : 2025-04-17 09:00:11
# 加到我的最愛 | 說明
# 詳細資料
# 免費文字聊天: 免費一對多
# ================================================================================
#
# ================================================================================
# Record 21
# URL: http://356.schoollibrary.edu.pe.ca/cgi-bin/koha/opac-search.pl?q=su:Painters%20%20and%20su:United%20States%20%20and%20su:Biography&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=branch:356&limit=su-to:Artists.&limit=su-to:Artists.&limit=su-to:Art%20appreciation.&limit=se:Getting%20to%20know%20the%20world's%20greatest%20artists&limit=su-to:Painters&limit=su-to:Artists.&limit=au:Venezia,%20Mike.&limit=se:Getting%20to%20know%20the%20world's%20greatest%20artists&limit=se:Getting%20to%20know%20the%20world's%20greatest%20artists&limit=su-to:Artists.&limit=su-to:Painting,%20American.&limit=se:Getting%20to%20know%20the%20world's%20greatest%20artists&limit=su-to:Art%20appreciation.&limit=se:Getting%20to%20know%20the%20world's%20greatest%20artists&limit=su-to:Artists.&sort_by=relevance_asc&limit=available
# Content length: 1595 chars
# First 500 chars:
# PEI School Library System Catalog › Results of Search for 'su:Painters and su:United States and su:Biography' with limit(s): 'branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 branch:356 su-to:Artists. su-to:Artists. su-to:Art appreciation. se:Getting to know the world's greatest artists su-to:Painters su-to:Artists. au:Venezia, Mike. se:Getting to know the world's greate
# ================================================================================
#
# ================================================================================
# Record 22
# URL: http://366392.haaxz.com/?PUT=a_show&AID=104124&FID=366392&R2=&CHANNEL=
# Content length: 4938 chars
# First 500 chars:
# 情色線上影片
# 回首頁 點數補給站 會員專區 加入會員 使用說明 付款方式 問題反映
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** -贈點10,000 點 No.2 LV28160** -贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點
# No.7 LV37566** -贈點4,000 點 No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# 頻道指數 限制級(火辣) 輔導級(曖昧) 普通級(清純)
# 排序 業績排行│ 一對多收費排序│ 一對一收費排序
# 頻道 台妹專區│ 新人區│ 一對一視訊區│ 一對多視訊區│ 免費聊天區│ 免費視訊區
# 搜尋主持人網名/編號：
# (夏之雪) 一對一忙線中 最近上線時間 : 2025-04-18 00:11:02
# 免費聊天 進入包廂 送禮 給主持人打分數
# ================================================================================
#
# ================================================================================
# Record 23
# URL: http://366392.haaxz.com/?PUT=a_show&AID=130260&FID=366392&R2=&CHANNEL=
# Content length: 2715 chars
# First 500 chars:
# 情色線上影片
# 回首頁 點數補給站 會員專區 加入會員 使用說明 付款方式 問題反映
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** -贈點10,000 點 No.2 LV28160** -贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點
# No.7 LV37566** -贈點4,000 點 No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# 頻道指數 限制級(火辣) 輔導級(曖昧) 普通級(清純)
# 排序 業績排行│ 一對多收費排序│ 一對一收費排序
# 頻道 台妹專區│ 新人區│ 一對一視訊區│ 一對多視訊區│ 免費聊天區│ 免費視訊區
# 搜尋主持人網名/編號：
# (雙幕幕) 最近上線時間 : 2025-04-17 05:41:42
# 免費聊天 進入包廂 送禮 給主持人打分數 加到我的最愛
# ================================================================================
#
# ================================================================================
# Record 24
# URL: http://387tel.com/index.phtml?PUT=a_show&AID=244724&FID=1361125&R2=&CHANNEL=
# Content length: 836 chars
# First 500 chars:
# 387tel 視訊聊天交友網
# 會員登入
# 加入會員
# 業績排行
# 分鐘數排行
# 已消費會員數
# 平均分鐘數
# 會員評價
# 上線時間
# 聊天人緣
# 包廂線上人數
# 一對多點數
# 一對一點數
# 網站新人
# 上線狀態排序
# 網站推薦
# 已審核本人照
# 談情說愛
# 成人視訊
# 好消息！9月9日起，免費
# 視訊聊天室正式開跑囉！
# 歡迎哥哥、妹妹一起來~ ^^
# 好消息！9月9日起，免費
# 視訊聊天室正式開跑囉！
# 歡迎哥哥、妹妹一起來~ ^^
# 恭喜三月份消費排行前十名會員 獲得免費點數~
# No.1 LV75699** -贈點10,000 點 No.2 LV28160** -贈點9,000 點
# No.3 LV72247** -贈點8,000 點 No.4 LV52777** -贈點7,000 點 No.5 LV65749** -贈點6,000 點 No.6 LV68540** -贈點5,000 點
# No.7 LV37566** -贈點4,000 點 No.8 LV71975** -贈點3,000 點 No.9 LV25850** -贈點2,000 點 No.10 LV16730** -贈點1,000 點
# 免費聊天
# 進入包廂
# 送禮
# 免費文字聊
# ================================================================================
#
# ================================================================================
# Record 25
# URL: http://3diasdemarzo.blogspot.com/2005/04/el-gobierno-no-entregar-la.html
# Content length: 9232 chars
# First 500 chars:
# 3 días de marzo: El Gobierno no entregará la transcripción de la conversación entre Huarte y Bensmail porque afecta al derecho a la intimidad del prisionero
# skip to main | skip to sidebar
# EDITORIAL | TITULARES | AUTORÍA DEL 11-M | ARTÍCULOS DE OPINIÓN | MULTIMEDIA | RESEÑAS | LINKS
# 20/4/05
# El Gobierno no entregará la transcripción de la conversación entre Huarte y Bensmail porque afecta al derecho a la intimidad del prisionero
# El Gobierno del PP desechó por irrelevantes en 2002 grabaciones de Hu
# ================================================================================

# %% [markdown]
# ## 2.2 HTML to text conversion
#
# ### (a) Extract text from HTML bytes using Resiliparse

# %%
from cs336_data.extract import extract_text_from_html_bytes

# %% [markdown]
# ### (b) Compare Resiliparse extraction vs WET extraction on the first page

# %%
# Extract text from the first WARC response using our function, and compare with WET
from warcio.archiveiterator import ArchiveIterator

# Get Resiliparse extraction from WARC
resiliparse_text = None
with open(WARC_PATH, "rb") as f:
    for record in ArchiveIterator(f):
        if record.rec_type == "response":
            html_bytes = record.content_stream().read()
            resiliparse_text = extract_text_from_html_bytes(html_bytes)
            warc_url = record.rec_headers.get_header('WARC-Target-URI')
            break

# Get WET extraction
wet_text = None
with open(WET_PATH, "rb") as f:
    for record in ArchiveIterator(f):
        if record.rec_type == "conversion":
            wet_text = record.content_stream().read().decode('utf-8', errors='replace')
            break

print(f"URL: {warc_url}")
print(f"Resiliparse output length: {len(resiliparse_text)} chars")
print(f"WET output length:         {len(wet_text)} chars")
print()
print("=" * 80)
print("RESILIPARSE EXTRACTION (first 2000 chars)")
print("=" * 80)
print(resiliparse_text[:2000])
print()
print("=" * 80)
print("WET EXTRACTION (first 2000 chars)")
print("=" * 80)
print(wet_text[:2000])
# Out:
# URL: http://0371rykj.com/ipfhsb/34.html
# Resiliparse output length: 10165 chars
# WET output length:         3496 chars
#
# ================================================================================
# RESILIPARSE EXTRACTION (first 2000 chars)
# ================================================================================
# 久久久久女人精品毛片,99久久精品无码一区二区毛片,被老外的又粗又大日出了水,一边吃奶一边哭乱抻又乱扭
#
#         • <th id="gckmo"></th>
#         • <ul id="gckmo"><center id="gckmo"></center></ul>
#       •
#
#
#
#
#
#
#
#
#
#
#         恒溫恒濕試驗(yàn)箱
#
# 	在線(xiàn)咨詢(xún)
#
#
#
#
#       淋雨試驗(yàn)箱
#
#         上海林頻儀器股份有限公司Shanghai Linpin Instrument Stock Co Ltd
#
#
#         服務(wù)熱線(xiàn)：4000 662 888
#          手機(jī)咨詢(xún)：13818467052
#
#
#
#
#
#
#
#
#
#         • 首頁(yè)
#           •
#
#
#         •
# 	  林頻產(chǎn)品
#
#
#
#
#           • 試驗(yàn)箱系列
#           • 老化箱系列
#           • 非標(biāo)定制系列
#           • ip防護(hù)系列
#           • 振動(dòng)跌落系列
#             •
#
#
#
#
#         •
# 	  成功案例
#
#
#
#
#
#
#
#
#         •
# 	  新聞中心
#
#
#
#
#           • 林頻新聞
#           • 行業(yè)新聞
#           • 常見(jiàn)問(wèn)題
#             •
#
#
#
#
#         •
# 	  解決方案
#
#
#
#
#
#
#
#
#         •
# 	  關(guān)于林頻
#
#
#
#
#
#
#
#
#         •
# 	  服務(wù)支持
#
#
#
#
#
#
#
#
#         •
# 	  聯(lián)系我們
#
#
#
#
#
#
#
#
#           •
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		    您所在的位置：
#
#
#
# 			 恒溫恒濕試驗(yàn)箱 > 林頻產(chǎn)品 > ip防護(hù)系列 >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         產(chǎn)品詳情/ products details
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ================================================================================
# WET EXTRACTION (first 2000 chars)
# ================================================================================
# 人妻,国内老熟妇对白HDXXXX,亚洲AV无码一区东京热久久
# 久久久久女人精品毛片,99久久精品无码一区二区毛片,被老外的又粗又大日出了水,一边吃奶一边哭乱抻又乱扭
# 恒溫恒濕試驗(yàn)箱
# 在線(xiàn)咨詢(xún)
# 上海林頻儀器股份有限公司Shanghai Linpin Instrument Stock Co Ltd
# 服務(wù)熱線(xiàn)：4000 662 888
# 手機(jī)咨詢(xún)：13818467052
# 首頁(yè)
# 林頻產(chǎn)品
# 試驗(yàn)箱系列
# 老化箱系列
# 非標(biāo)定制系列
# ip防護(hù)系列
# 振動(dòng)跌落系列
# 成功案例
# 新聞中心
# 林頻新聞
# 行業(yè)新聞
# 常見(jiàn)問(wèn)題
# 解決方案
# 關(guān)于林頻
# 服務(wù)支持
# 聯(lián)系我們
# 您所在的位置：
# 恒溫恒濕試驗(yàn)箱 > 林頻產(chǎn)品 > ip防護(hù)系列 >
# 產(chǎn)品詳情/ products details
# 恒溫恒濕試驗(yàn)箱
# 產(chǎn)品用途
# 恒溫恒濕試驗(yàn)箱是航空、汽車(chē)、家電、科研等領(lǐng)域必備的測(cè)試設(shè)備，用于測(cè)試和確定電工、電子及其他產(chǎn)品及材料進(jìn)行高溫、低溫、濕熱度或恒定試驗(yàn)的溫度環(huán)境變化后的參數(shù)及性能。...
# 了解詳情 立即咨詢(xún)
# 產(chǎn)品參數(shù) / parameter
# 設(shè)備型號(hào) 工作室尺寸(D*W*H)mm 外型尺寸(D*W*H)mm
# LRHS-101-LH 450×450×500 1160×1000×1610
# LRHS-225-LH 500×600×750 1210×1150×1870
# LRHS-504-LH 700×800×900 1260×1340×2070
# LRHS-800-LH 800×1000×1000 1370×1550×2170
# LRHS-1000-LH 1000×1000×1000 1560×1550×2170
# 性
# 能
# 指
# 標(biāo) 溫度范圍 0℃～150℃
# 溫度均勻度 ≤2℃（空載時(shí)）
# 溫度波動(dòng)度 ±0.5℃（空載時(shí)）
# 濕度范圍 20%～98% RH
# 濕度均勻度 +2% -3% RH
# 濕度波動(dòng) ±2%
# 升溫速率 1.0～3.0℃/min
# 降溫速率 0.7～1.0℃/min
# 時(shí)間設(shè)定范圍 1～60000M
# 測(cè)試孔 安裝在機(jī)器左側(cè)，用于外接測(cè)試電源線(xiàn)或信號(hào)線(xiàn)使用
# 觀(guān)察窗 210×275mm或395×395mm（有效視界）
# 使
# 用
# 材
# 料 外箱材質(zhì) 優(yōu)質(zhì)A3鋼板靜電噴塑
# 內(nèi)箱材質(zhì) 進(jìn)口高級(jí)不銹鋼SUS304
# 保溫材質(zhì) 硬質(zhì)聚氨酯泡沫+玻璃纖維
# 核
# 心
# 配
# 置 溫度控制器 日本原裝進(jìn)口“優(yōu)易控”品牌溫濕度儀表
# 溫度傳感器 PT100鉑金電阻測(cè)溫體
# 制冷方式 單機(jī)制冷
# 壓 縮 機(jī) 法國(guó)泰康
# 標(biāo)準(zhǔn)配置 濕球紗布1卷、樣品架2層、配有凝結(jié)水接水盤(pán)，并排出箱外
# 安全保護(hù) 壓縮機(jī)過(guò)熱、超壓、超溫、風(fēng)機(jī)電機(jī)過(guò)熱、整體設(shè)備欠相/逆相 整體設(shè)備定時(shí)、漏電保護(hù)、
# 過(guò)載及短路保護(hù)
# 電源電壓 AC380V±10% 50Hz
# 功 率 4.0KW/5.5KW/8.5KW/11.5KW/11.5KW
# 使用環(huán)境 5℃～＋28℃ ≤85% RH
# 注：
# 1、以上數(shù)據(jù)均在使用環(huán)境溫度為25℃時(shí)且通風(fēng)良好條件下測(cè)得
# 2、可根據(jù)用戶(hù)具體試驗(yàn)要求非標(biāo)定制恒溫恒濕試驗(yàn)室等
# 3、本技術(shù)信息，如有變動(dòng)恕不另行通知
# 上一篇：武漢冷凝水試驗(yàn)箱|冷凝水實(shí)驗(yàn)箱|冷凝水測(cè)試箱使用說(shuō)明 下一篇：武漢軍標(biāo)淋雨試驗(yàn)室|軍標(biāo)淋雨實(shí)驗(yàn)箱|軍標(biāo)淋雨箱
# ip防護(hù)系列
# 試驗(yàn)箱系列
# 復(fù)合鹽霧箱
# 轉(zhuǎn)臺(tái)試驗(yàn)箱
# 高低溫試驗(yàn)箱
# 酒精低溫沖擊槽
# 老化箱系列
# 低溫綜合試驗(yàn)箱
# 水冷氙燈耐氣候試

# %% [markdown]
# ## 2.3 Language identification
#
# ### Setup: Download fastText language ID model

# %%
LID_MODEL_PATH = os.path.join(DATA_DIR, "lid.176.bin")
if not os.path.exists(LID_MODEL_PATH):
    # !wget -O {LID_MODEL_PATH} "https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin"
else:
    print(f"Language ID model already exists at {LID_MODEL_PATH}")
# Out:
# Language ID model already exists at /content/LLM-from-scratch/ece405_assignment2/data/lid.176.bin

# %% [markdown]
# ### (a) Language identification function

# %%
from cs336_data.language_identification import identify_language, set_lid_model_path

set_lid_model_path(LID_MODEL_PATH)

# Quick sanity checks
print(identify_language("Hello, this is a test in English."))
print(identify_language("欢迎来到我们的网站"))
print(identify_language("Bonjour, comment allez-vous?"))
# Out:
# ('en', 0.9398366808891296)
# ('zh', 1.000056266784668)
# ('fr', 0.9740094542503357)

# %% [markdown]
# ### (c) Run language ID on 20 random WET records, compare to manual judgment

# %%
import random
from warcio.archiveiterator import ArchiveIterator

# Collect first 200 WET records, then sample 20
records = []
with open(WET_PATH, "rb") as f:
    for record in ArchiveIterator(f):
        if record.rec_type == "conversion":
            url = record.rec_headers.get_header('WARC-Target-URI')
            content = record.content_stream().read().decode('utf-8', errors='replace')
            if len(content.strip()) > 50:  # skip near-empty records
                records.append((url, content))
            if len(records) >= 200:
                break

random.seed(42)
sample = random.sample(records, 20)

print(f"Sampled {len(sample)} records from {len(records)} total\n")

for i, (url, content) in enumerate(sample):
    lang, score = identify_language(content)
    print(f"Record {i+1:2d} | lang={lang:5s} score={score:.4f} | {url}")
    print(f"           First 120 chars: {content[:120].replace(chr(10), ' ')}")
    print()
# Out:
# Sampled 20 records from 200 total
#
# Record  1 | lang=id    score=0.5478 | http://bagsguccistoer.com/rise%20of%20apollo%20pg
#            First 120 chars: แนะนำ 10 rise of apollo pg ไม่ผ่านเอเย่นต์ งบน้อยเล่นได้ ฝากถอนไม่มีขั้นต่ำ INTERNAL FEEDBACK rise of apollo pg สล็อตเว็
#
# Record  2 | lang=zh    score=0.9596 | http://50899.cn/news/16755.html
#            First 120 chars: A级毛片无码真人久久久,欧美性饥渴少妇BBB.BBB片 午夜亚洲影院在线观看,日韩欧美精品视频一区二区三区,久免费视频,黄网人妻视频,99视频在线观看精品,午夜A级性爱 BJFQY 經(jīng)營品牌 風(fēng)富圖 佳能 大疆 寶麗
#
# Record  3 | lang=zh    score=0.9951 | http://18sex.v340.info/?&R2=&P=11&OP=&CHANNEL=
#            First 120 chars: 本土自拍性愛影片 回 首 頁 │ 點數購買 │ 付款方式 │ 加入會員 │會員登入 │主持人登入 │ 線上客服 │使用說明 │ 使用條款 │ 台妹區 | 內地主播區 | 業績排行 | 會員評價 | 包廂線上人數 | 一對多點數 | 一對一點
#
# Record  4 | lang=en    score=0.8122 | http://beyparkotel.com/
#            First 120 chars: Beypark Otel Your browser does not support frames. Untitled Page
#
# Record  5 | lang=ru    score=0.9911 | http://agrokenya.org/2024/02/10/kak-mozhno-zarabotat-realnye-pin-up-skachat-na-telefon-dengi-v-igornom-zavedenii-v-seti/
#            First 120 chars: Welcome to the home of smallholder farmers. Open/Close Menu Making the farmer the hero  Skip to content Home Projects A
#
# Record  6 | lang=zh    score=0.9805 | http://adult.twlive520.info/index.phtml?PUT=a_show&AID=218782&FID=391607&R2=&CHANNEL=
#            First 120 chars: 潮吹貼圖聊天館 會員登入 加入會員 業績排行 分鐘數排行 已消費會員數 平均分鐘數 會員評價 上線時間 聊天人緣 包廂線上人數 一對多點數 一對一點數 網站新人 上線狀態排序 網站推薦 已審核本人照 談情說愛 成人視訊 好消息！9月9日起，
#
# Record  7 | lang=pt    score=0.6847 | http://acorsan.com.br/caixa-dagua-cilindrico-vertical-com-fundo-reto
#            First 120 chars: Reservatório Metálico | 16-99795-2844 | Caixa d'água | Castelo d'água - Caixa d'água Cilíndrico Vertical com Fundo Reto
#
# Record  8 | lang=fr    score=0.9365 | http://8-0.fr/tag/pinterest/
#            First 120 chars: 8-0.fr » Pinterest : démission du CEO À propos Contact Boutique Pinterest : démission du CEO avril 06th, 2012 | Category
#
# Record  9 | lang=en    score=0.8483 | http://betag.pasty.com/login.php?reload_once&referer=displayimage.php%3Fpid%3D36808&message_id=1e00f393b58b647100ab981eab48b360&message_icon=info
#            First 120 chars: Login - Pasty Gallery Pasty Gallery pasty.com Home Login Album list Last uploads Last comments Most viewed Top rated My
#
# Record 10 | lang=en    score=0.9194 | http://4381productions.com/author/admin/
#            First 120 chars: KRH – 4381 Productions Home About Blog Challenges Demos Montague Street 0 Cart Home About Blog Challenges Demos Montague
#
# Record 11 | lang=zh    score=0.9870 | http://bbs.chenruo.net/thread-55247-1-1.html
#            First 120 chars: 240824 캔디샵(Candy Shop) 龟船夏日夜庆典直拍8则 수이(SUI) Don’t Cry 직캠(FanCam)[百度网盘609M] - 女团饭拍 - 晨若资源分享论坛——学习资源丰富，视频课程很全的中文分享社区网! - Po
#
# Record 12 | lang=en    score=0.9187 | http://ask.mallaky.com/cgi-sys/suspendedpage.cgi?qa=user/u8888asia
#            First 120 chars: This page is currently unavailable If you are the webmaster for this site, please contact your hosting provider's suppor
#
# Record 13 | lang=es    score=0.9738 | http://3diasdemarzo.blogspot.com/2005/04/el-gobierno-no-entregar-la.html
#            First 120 chars: 3 días de marzo: El Gobierno no entregará la transcripción de la conversación entre Huarte y Bensmail porque afecta al d
#
# Record 14 | lang=ko    score=1.0000 | http://atis.koca.go.kr/ATIS/lihgtAircraftRegStat/forwardPage.do;jsessionid=50B18F3CF516A07CBA693DA0932AD6EF?pageUrl=lightAircraftRegStat07
#            First 120 chars: ATIS 항공기술정보시스템 본문으로 가기 HOME HELP 공공데이터 이용정책 AIS ATIS 항공기 등록 항공기 등록현황 종류별/기령별 현황 정치장별 현황 연도별/월별 현황 사업구분별 현황 업체별 현황 연도별 도입
#
# Record 15 | lang=es    score=0.9430 | http://apisred.blogspot.com/2013/09/estudiantes-del-sena-del-curso.html
#            First 120 chars: APISRED: Estudiantes del SENA del Curso "Tecnologo en gestion comercial de servicios" desarrollan proyecto en Apisred. l
#
# Record 16 | lang=el    score=0.9998 | http://1pekesat-exae.mysch.gr/exae/search.php?sid=c7c6170adb93afd9c9d00950dd818d3d
#            First 120 chars: Helpdesk εξΑΕ 1ου ΠΕΚΕΣ Αττικής - Αναζήτηση Helpdesk εξΑΕ 1ου ΠΕΚΕΣ Αττικής Υποστηρικτική Ομάδα για την εξ αποστάσεως Εκ
#
# Record 17 | lang=nl    score=0.9306 | http://1kb.klimtoren.be/2016/06/blog-post_30.html
#            First 120 chars: 1KB - Juf Marijke 1KB - Juf Marijke donderdag 30 juni 2016 Hoera voor Leonie! 4 Jaar :-) Gepost door juf marijke op 09:2
#
# Record 18 | lang=da    score=0.8472 | http://3godetilbud.dk/vinduespolering/skov-8/
#            First 120 chars: Vinduespolering i Skov - Få 3 gratis og uforpligtende tilbud her! Hop til indhold 3godetilbud.dk Menu Vinduespolering Sk
#
# Record 19 | lang=en    score=0.8938 | http://acnn.akubihar.ac.in/Default.aspx
#            First 120 chars: AKU : Nano Technology +91 810 292 6986 Call us WEB MAIL | Query Us @ Menu Home National Advisory Com. CAREERS in Nano He
#
# Record 20 | lang=zh    score=0.9896 | http://admin-b2b.javamall.com.cn/goods?category=27
#            First 120 chars: 商品列表-宇仓演示示例电商系统 您好，欢迎来到宇仓演示示例电商系统[登录] [注册] 我的订单 待付款订单 待收货订单 待评价订单 我的收藏 收藏的商品 站点导航 商城首页 个人中心 帮助中心 站内消息[0] 搜商品 猫粮 狗粮 猪饲料 女

# %% [markdown]
# ## 2.4 PII masking
#
# ### (a)–(c) PII masking functions

# %%
from cs336_data.pii import mask_emails, mask_phone_numbers, mask_ips

# Sanity checks
print(mask_emails("Contact me at test@gmail.com or admin@example.org"))
print(mask_phone_numbers("Call (283)-182-3829 or 2831823829"))
print(mask_ips("Server at 192.0.2.146 and 10.0.0.1"))

# %% [markdown]
# ### (5) Run PII masking on extracted text, examine 20 random replacements

# %%
import random
from warcio.archiveiterator import ArchiveIterator
from cs336_data.extract import extract_text_from_html_bytes
from cs336_data.pii import mask_emails, mask_phone_numbers, mask_ips

# Extract text from WARC pages and apply PII masking
pii_results = []
with open(WARC_PATH, "rb") as f:
    for record in ArchiveIterator(f):
        if record.rec_type == "response":
            html_bytes = record.content_stream().read()
            text = extract_text_from_html_bytes(html_bytes)
            if text and len(text.strip()) > 100:
                masked_email, n_emails = mask_emails(text)
                masked_phone, n_phones = mask_phone_numbers(masked_email)
                masked_all, n_ips = mask_ips(masked_phone)
                total = n_emails + n_phones + n_ips
                if total > 0:
                    pii_results.append({
                        "url": record.rec_headers.get_header('WARC-Target-URI'),
                        "original": text,
                        "masked": masked_all,
                        "n_emails": n_emails,
                        "n_phones": n_phones,
                        "n_ips": n_ips,
                    })
        if len(pii_results) >= 100:
            break

print(f"Found {len(pii_results)} pages with PII out of first ~100+ WARC responses\n")

# Show 20 random examples
random.seed(42)
sample = random.sample(pii_results, min(20, len(pii_results)))

for i, r in enumerate(sample):
    print(f"{'='*80}")
    print(f"Example {i+1} | URL: {r['url']}")
    print(f"  Emails: {r['n_emails']}, Phones: {r['n_phones']}, IPs: {r['n_ips']}")
    # Show context around each replacement
    for marker in ["|||EMAIL_ADDRESS|||", "|||PHONE_NUMBER|||", "|||IP_ADDRESS|||"]:
        idx = 0
        while True:
            pos = r["masked"].find(marker, idx)
            if pos == -1:
                break
            start = max(0, pos - 40)
            end = min(len(r["masked"]), pos + len(marker) + 40)
            context = r["masked"][start:end].replace("\n", " ")
            print(f"  ...{context}...")
            idx = pos + len(marker)
    print()

# %% [markdown]
# ## 2.5 Harmful content classification
#
# ### Setup: Download Dolma fastText classifiers

# %%
NSFW_MODEL_PATH = os.path.join(DATA_DIR, "dolma_fasttext_nsfw_jigsaw_model.bin")
TOXIC_MODEL_PATH = os.path.join(DATA_DIR, "dolma_fasttext_hatespeech_jigsaw_model.bin")

if not os.path.exists(NSFW_MODEL_PATH):
    # !wget -O {NSFW_MODEL_PATH} "https://huggingface.co/allenai/dolma-jigsaw-fasttext-bigrams-nsfw/resolve/main/model.bin"
else:
    print(f"NSFW model already exists at {NSFW_MODEL_PATH}")

if not os.path.exists(TOXIC_MODEL_PATH):
    # !wget -O {TOXIC_MODEL_PATH} "https://huggingface.co/allenai/dolma-jigsaw-fasttext-bigrams-hatespeech/resolve/main/model.bin"
else:
    print(f"Toxic speech model already exists at {TOXIC_MODEL_PATH}")

# %% [markdown]
# ### (1)–(2) NSFW and toxic speech classifiers

# %%
from cs336_data.harmful_content import classify_nsfw, classify_toxic_speech, set_nsfw_model_path, set_toxic_model_path

set_nsfw_model_path(NSFW_MODEL_PATH)
set_toxic_model_path(TOXIC_MODEL_PATH)

# Sanity checks
print("NSFW classifier:")
print(classify_nsfw("This is a normal sentence about cooking."))
print(classify_nsfw("SUCK MY C*CK WIKIPEDIA EDITORS...F*CKING *SSH*LE DORKS."))
print()
print("Toxic speech classifier:")
print(classify_toxic_speech("The weather is nice today."))
print(classify_toxic_speech("What a rude fuck. Arrogant twat who doesn't know what he's talking about."))

# %% [markdown]
# ### (4) Run on extracted text, compare 20 predictions to own judgment

# %%
import random
from warcio.archiveiterator import ArchiveIterator
from cs336_data.extract import extract_text_from_html_bytes

# Extract text from first 200 WARC pages
texts = []
with open(WARC_PATH, "rb") as f:
    for record in ArchiveIterator(f):
        if record.rec_type == "response":
            html_bytes = record.content_stream().read()
            text = extract_text_from_html_bytes(html_bytes)
            url = record.rec_headers.get_header('WARC-Target-URI')
            if text and len(text.strip()) > 100:
                texts.append((url, text))
        if len(texts) >= 200:
            break

random.seed(42)
sample = random.sample(texts, 20)

print(f"Sampled {len(sample)} pages from {len(texts)} total\n")

for i, (url, text) in enumerate(sample):
    nsfw_label, nsfw_score = classify_nsfw(text)
    toxic_label, toxic_score = classify_toxic_speech(text)
    print(f"Record {i+1:2d} | nsfw={nsfw_label:8s} ({nsfw_score:.4f}) | toxic={toxic_label:9s} ({toxic_score:.4f}) | {url}")
    print(f"           First 120 chars: {text[:120].replace(chr(10), ' ')}")
    print()
